# %% [markdown]
# <a href="https://colab.research.google.com/github/VitalyGladyshev/Python_for_DS/blob/master/%D0%93%D0%BB%D0%B0%D0%B4%D1%8B%D1%88%D0%B5%D0%B2%D0%92%D0%92_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# plot_format = 'png'
# fig.show(plot_format)

# %%
# !wget --no-check-certificate -r 'https://drive.google.com/file/d/1Kb78mAWYKcYlellTGhIjPI-bCcKbGuTn' -O data.csv
# !gdown --id 1Kb78mAWYKcYlellTGhIjPI-bCcKbGuTn
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Kb78mAWYKcYlellTGhIjPI-bCcKbGuTn
# From (redirected): https://drive.google.com/uc?id=1Kb78mAWYKcYlellTGhIjPI-bCcKbGuTn&confirm=t&uuid=d4cfc7ec-ebe8-4fb4-9bc9-bda867ec72bf
# To: /content/dst-3.0_16_1_hh_database.csv
# 100% 455M/455M [00:06<00:00, 73.3MB/s]

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
data = pd.read_csv("/content/dst-3.0_16_1_hh_database.csv", sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
def preprocess(txt: str):
    words = txt.split()
    if words[0] == "Неоконченное":
        return "неоконченное высшее"
    elif words[0] == "Высшее":
        return "высшее"
    elif words[0] == "Среднее":
        if words[1] == "специальное":
            return "среднее специальное"
        else:
            return "среднее"
    else:
        return "другое"


data['Образование'] = data['Образование и ВУЗ'].apply(preprocess)
data.drop('Образование и ВУЗ', axis=1, inplace=True)

# print(data['Образование'].unique())
print(data.value_counts("Образование")['среднее'])
# Out:
# 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь data['Пол, возраст'][0]

def preprocess_sex(txt: str):
    words = txt.split(',')
    if words[0].strip() == "Мужчина":
        return "М"
    else:
        return "Ж"


def preprocess_age(txt: str):
    words = txt.split(',')
    age = words[1].split()

    return int(age[0])


data['Пол'] = data['Пол, возраст'].apply(preprocess_sex)
data['Возраст'] = data['Пол, возраст'].apply(preprocess_age)
data.drop('Пол, возраст', axis=1, inplace=True)

print(round(data.value_counts("Пол")['Ж']/data.shape[0]*100, 2))
print(round(data['Возраст'].mean(), 2))
# Out:
# 19.07
# 32.2

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def preprocess(txt):

    if pd.isna(txt):
        return np.nan

    if txt == "Не указано":
        return np.nan

    words = txt.split()

    if words[3][:3] != 'мес':
        if words[5][:3] == 'мес':
            return int(int(words[2]) * 12) + int(words[4])
        else:
            return int(int(words[2]) * 12)
    else:
        return int(words[2])


data['Опыт работы (месяц)'] = data['Опыт работы'].apply(preprocess)
data.drop('Опыт работы', axis=1, inplace=True)

# print(f"{preprocess(data['Опыт работы'][64])} {data['Опыт работы'][64]}")
# data.loc[data['Опыт работы'].isna() == True, 'Опыт работы']
data.loc[data['Опыт работы (месяц)'].isna() == False, 'Опыт работы (месяц)'].median()
# Out:
# 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань',
                  'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа',
                  'Красноярск', 'Пермь', 'Воронеж','Волгоград']


def preprocess_city(txt: str):
    words = txt.split(',')
    if words[0].strip() == "Москва":
        return "Москва"
    elif words[0].strip() == "Санкт-Петербург":
        return "Санкт-Петербург"
    elif words[0].strip() in million_cities:
        return "город-миллионник"
    else:
        return "другие"


def preprocess_removal(txt: str):
    words = txt.split(',')
    ind = 1
    if words[1][:3] == "м. ":
        ind += 1

    removal = words[ind].split()
    if "не" in removal:
        return False
    else:
        return True


def preprocess_trip(txt: str):
    words = txt.split(',')
    trip = words[-1].split()
    if "командировкам" in trip:
        if "не" in trip:
            return False
        else:
            return True
    else:
        return False


# функци преобразования готовности к переезду
def mov_ready(move):
    if move.find('не готов к переезду') != -1 or move.find('не готова к переезду') != -1:
        return False
    else: return True

# функция преобразования готовности к командировкам
def bus_trip(bt):
    if bt.find('не готов к командировкам') != -1 or bt.find('не готова к командировкам') != -1:
        return False
    if bt.find('командир') == -1:
        return False
    else: return True


data['Город'] = data['Город, переезд, командировки'].apply(preprocess_city)
data['Готовность к переезду'] = data['Город, переезд, командировки'].apply(mov_ready)
data['Готовность к командировкам'] = data['Город, переезд, командировки'].apply(bus_trip)
data.drop('Город, переезд, командировки', axis=1, inplace=True)

# print(f"{preprocess_city(data['Город, переезд, командировки'][0])} {data['Город'][0]}")
print(round(data.value_counts("Город")['Санкт-Петербург']/data.shape[0]*100))
print(round(data.loc[data['Готовность к переезду'] & data['Готовность к командировкам']].shape[0]/data.shape[0]*100))
# Out:
# 11
# 32

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Преобразуем занятость в признаки-мигалки
data['Полная занятость'] = data['Занятость'].apply(lambda x: x.find('полная занятость') != -1)
data['Частичная занятость'] = data['Занятость'].apply(lambda x: x.find('частичная занятость') != -1)
data['Проектная работа'] = data['Занятость'].apply(lambda x: x.find('проектная работа') != -1)
data['Стажировка'] = data['Занятость'].apply(lambda x: x.find('стажировка') != -1)
data['Волонтерство'] = data['Занятость'].apply(lambda x: x.find('волонтерство') != -1)

# Преобразуем график в признаки-мигалки
data['Вахтовый метод'] = data['График'].apply(lambda x: x.find('вахтовый метод') != -1)
data['Гибкий график'] = data['График'].apply(lambda x: x.find('гибкий график') != -1)
data['Удаленная работа'] = data['График'].apply(lambda x: x.find('удаленная работа') != -1)
data['Полный день'] = data['График'].apply(lambda x: x.find('полный день') != -1)
data['Сменный график'] = data['График'].apply(lambda x: x.find('сменный график') != -1)

# проверим обработку Занятости и ответим на вопрос:
# Сколько людей ищут проектную работу или волонтёрство (в обоих столбцах стоит True)
display(data[(data['Проектная работа'] == True) & (data['Волонтерство'] == True)].shape[0])

# проверим обработку Графика и ответим на вопрос:
# Сколько людей ищут проектную работу или волонтёрство (в обоих столбцах стоит True)
display(data[(data['Вахтовый метод'] == True) & (data['Гибкий график'] == True)].shape[0])

# удаляем столбцы Занятость и График работы
data = data.drop('Занятость', axis=1)
data = data.drop('График', axis=1)
# Out:
# 436
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
# прочитаем данные с курсами валют
ex_rates = pd.read_csv('ExchangeRates.csv', sep=',')

# переведем даты в формат datetime и оставим только даты
data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме']).dt.date
data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме'])
ex_rates['date'] = pd.to_datetime(ex_rates['date'])

# выделим признаки ЗП и валюты
data['Сумма'] = data['ЗП'].apply(lambda x: x.split(' ')[0])
data['Валюта'] = data['ЗП'].apply(lambda x: x.split(' ')[1])

# изучим признаки валюты
display(data['Валюта'].unique())

# функция перевода валюты в стандарт ISO (где необходимо)
def cur_iso(curr):
    if curr == 'бел.руб.': return 'BYN'
    if curr == 'грн.': return 'UAH'
    if curr == 'сум': return 'UZS'
    else: return curr

# приведем валюту в стандарт ISO
data['Валюта'] = data['Валюта'].apply(cur_iso)

# присоединим таблицу с курсами
data = data.merge(
    ex_rates,
    left_on=['Обновление резюме','Валюта'],
    right_on=['date','currency'],
    how='left')

# проверим преобразование валюты и соответствие признаков в таблицах
print(data['Валюта'].value_counts())
print(data['currency'].value_counts())

# так как отсутствуют курсы и пропорции только по рублям - заменим значения в столбцах на константу (1)
data['close'] = data['close'].fillna(1)
data['proportion'] = data['proportion'].fillna(1)

# создадим признак ЗП в руб.
data['ЗП (руб)'] = data['Сумма'].astype('float64') * data['close'] / data['proportion']

# удаляем промежуточные и исходные столбцы
del_col = ['ЗП','Сумма','Валюта','currency','per','date','time','close','vol','proportion']
data.drop(del_col, axis=1, inplace=True)

# ответим на вопрос:
print(data['ЗП (руб)'].median())
print(round(data['ЗП (руб)'].median()/1000,0))
# Out:
# <ipython-input-122-4bc57ab1771d>:5: UserWarning: Parsing dates in %d.%m.%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме']).dt.date
# <ipython-input-122-4bc57ab1771d>:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ex_rates['date'] = pd.to_datetime(ex_rates['date'])
# array(['руб.', 'бел.руб.', 'KZT', 'EUR', 'USD', 'грн.', 'сум', 'KGS',
#        'AZN'], dtype=object)
# Валюта
# руб.    42471
# KZT      1108
# USD       628
# BYN       329
# EUR       106
# UAH        73
# UZS        20
# KGS         6
# AZN         3
# Name: count, dtype: int64
# currency
# KZT    1108
# USD     628
# BYN     329
# EUR     106
# UAH      73
# UZS      20
# KGS       6
# AZN       3
# Name: count, dtype: int64
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8))
axes[0].set_title('Распределение возраста соискателей', fontsize=14)
sns.histplot(data=data, x='Возраст', bins=25, kde=True, ax=axes[0]);
sns.boxplot(data=data, x='Возраст')
# Out:
# <Axes: xlabel='Возраст'>

# %% [markdown]
# - Мода распределения возраста соискателей находится на уровне от 28 до 32 лет (предположительно, 30 лет).
# - Минимальный возраст - около 14 лет, максимальный - 100 лет.
# - Возраст большинства соискателей находится в диапазоне от 27 до 36 лет.
# - Коробчатая диаграмма показывает выброс на уровне 100 лет - скорее всего, это аномалия (сознательно или ошибочно допущенная соискателями): в таком возрасте уже сложно выполнять функциональные обязанности даже на самых низших должностях.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 8))
axes[0].set_title('Распределение стажа работы соискателей, мес.', fontsize=14)
sns.histplot(data=data, x='Опыт работы (месяц)', bins=60, kde=True, ax=axes[0]);
sns.boxplot(data=data, x='Опыт работы (месяц)')
# Out:
# <Axes: xlabel='Опыт работы (месяц)'>

# %% [markdown]
# - Мода распределения стажа соискателей находится на уровне от 60 до 80 месяцев (предположительно, 70 месяцев).
# - Минимальный стаж - 0 месяцев (отсутствие опыта работы), максимальный - около 1190 месяцев.
# - Стаж большинства соискателей находится в диапазоне от 55 до 155 месяцев.
# - Коробчатая диаграмма показывает выброс на уровне около 1190 месяцев - это аномалия (сознательно или ошибочно допущенная соискателями): стажем на уровне 100 лет невозможно обладать, так как даже дожить до такого возраста непросто, а также потому что, как мы помним по предыдущему распределению, максимальный возраст соискателей - 100 лет, то есть максимальный стаж равен максимальному возрасту, что невозможно.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(15, 8))
axes[0].set_title('Распределение желаемой зарплаты соискателей, руб.', fontsize=14)
sns.histplot(data=data, x='ЗП (руб)', binwidth=50000, kde=True, ax=axes[0]);
sns.boxplot(data=data, x='ЗП (руб)')

# для удобства анализа ограничим ЗП на графиках уровнем в 2 млн руб.
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(15, 8))
axes[0].set_title('Распределение желаемой зарплаты соискателей (до 2 млн), руб.', fontsize=14)
sns.histplot(data=data[data['ЗП (руб)'] < 2000000], x='ЗП (руб)', binwidth=50000,
             kde=True, ax=axes[0]);
sns.boxplot(data=data[data['ЗП (руб)'] < 2000000], x='ЗП (руб)')

# ЗП > 1М
# print(data[data['ЗП (руб)'] > 1000000].shape[0])
# Out:
# <Axes: xlabel='ЗП (руб)'>

# %% [markdown]
# - Мода распределения желаемой зарплаты соискателей находится на уровне около 50 тысяч рублей.
# - Минимальный уровень желаемой зарплаты - около 0 рублей, максимальный - около 24,5 млн рублей.
# - Уровень желаемой зарплаты большинства соискателей находится в диапазоне от 40 до 100 тыс. рублей.
# - Коробчатая диаграмма показывает выброс на уровне около 24,5 млн руб. - видимо, это аномалия (сознательно или ошибочно допущенная соискателями): запрошенный уровень слишком сильно отличается от всех остальных запросов соискателей.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
from statistics import median
fig = plt.figure(figsize=(11, 5))
sns.set_theme(style="whitegrid")
barplot = sns.barplot(data=data[data['ЗП (руб)'] < 1000000], x='Образование',
                      y='ЗП (руб)', estimator=median,)
barplot.set_title('Зависимость медианной желаемой заработной платы от уровня образования \n (по данным о резюме с желаемой ЗП меньше 1 млн рублей)', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Зависимость медианной желаемой заработной платы от уровня образования \n (по данным о резюме с желаемой ЗП меньше 1 млн рублей)')

# %% [markdown]
# - Наивысший медианный уровень желаемой заработной платы демонстрируют соискатели с высшим образованием (около 60 тыс. руб.).
# - Следом идут желаемые ЗП соискателей с неоконченным высшим образованием (около 50 тыс. руб.).
# - Соискатели со средним и средним специальным образованием оценивают свой труд на одном уровне (около 40 тыс. руб.).

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
fig = plt.figure(figsize=(14, 6))
boxplot = sns.boxplot(data=data[data['ЗП (руб)'] < 1000000], x='ЗП (руб)', y='Город',
                      orient='h', width=0.9)
boxplot.set_title('Распределение желаемой заработной платы в зависимости от города \n (по данным о резюме с желаемой ЗП меньше 1 млн рублей)', fontsize=18);
boxplot.set_xlabel('Желаемая заработная плата');
boxplot.set_ylabel('Город');

# %% [markdown]
# - Наивысший медианный уровень желаемой заработной платы демонстрируют соискатели из Москвы (около 85 тыс. руб.).
# - Следом идут желаемые ЗП соискателей из Санкт-Петербурга (около 60 тыс. руб.).
# - Соискатели из городов-миллионников и других населенных пунктов оценивают свой труд на одном уровне (около 40 тыс. руб.).
# - Разброс желаемого уровня заработной платы большинства соискателей из Москвы (от 60 до 150 тыс. руб.) - наибольший по сравнению с остальными городами.
# - Разброс желаемого уровня заработной платы большинства соискателей из Санкт-Петербурга (от 45 до 85 тыс. руб.).
# - Разброс желаемого уровня заработной платы большинства соискателей из городов-миллионников и из других населенных пунктов находится на одном уровне (от 30 до 60 тыс. руб.).

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
catplot = sns.catplot(x="Готовность к переезду", y="ЗП (руб)", col="Готовность к командировкам",
                      data=data, kind="bar", estimator=median, height=5, aspect=.9);

# %% [markdown]
# - Медианный уровень желаемой заработной платы повышается с готовностью к переезду и еще более повышается с готовностью к командировкам: от 40 тыс. рублей для соискателей, не готовых к переезду и командировкам, до 65 тыс. рублей для соискателей, готовых и к переезду, и к командировкам.
# - Разброс медианных значений (35 тыс. рублей) составляет почти 88% от ожидаемой заработной платы соискателей, не готовых к переезду и командировкам - а значит, эти факторы являются значимыми и весомыми при анализе и прогнозировании заработной платы.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
pivot = data.pivot_table(values = 'ЗП (руб)', index = 'Образование',
                         columns = 'Возраст', aggfunc='median',)

# Тепловая карта
fig = plt.figure(figsize=(12, 5))
heatmap = sns.heatmap(data=pivot, cmap='YlGnBu')
heatmap.set_title('Тепловая карта зависимости медианной желаемой \n заработной платы от возраста и образования', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Тепловая карта зависимости медианной желаемой \n заработной платы от возраста и образования')

# %% [markdown]
# - Соискатели с высшим образованием в целом запрашивают более высокую заработную плату.
# - Соискатели со средним специальным образованием в целом запрашивают более низкую заработную плату.
# - Особенно высокую заработную плату ожидают соискатели с высшим образованием в возрасте 16 и 69 лет, соискатели с неоконченным высшим образованием в возрасте 58 лет, соискатели со средним образованием в возрасте 56 лет и соискатели со средним специальным образованием в возрасте 67 лет.
# - Соискатели с высшим образованием демонстрируют наибольший рост желаемой заработной платы с возрастом.
# - Желаемая заработная плата соискателей со средним специальным образованием наименее подвержена изменениям с возрастом (зависимость крайне низкая).

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
data['Стаж (лет)'] = data['Опыт работы (месяц)'] / 12

# Формируем диаграмму рассеяния
fig = plt.figure(figsize=(10, 6))
axes = fig.add_axes([0, 0, 1, 1])
graph = sns.scatterplot(data=data, x='Возраст', y='Стаж (лет)', hue='Город')
graph.set_title('Зависимость опыта работы от возраста', fontsize=18);

# добавляем диагональную линию - показывает прямое соотношение возраста и стажа, от 0 до 100 лет
sns.lineplot(x=[0, 100], y=[0, 100])

# добавляем еще одну диагональную линию - показывает более реальное соотношение возраста и стажа, принимаем,
# что стаж может начинаться не ранее возраста в 14 лет
sns.lineplot(x=[14, 100], y=[0, 86], linestyle='dashed')

# найдем количество точек выше синей и красной пунктирной линий
display(data[(data['Возраст'] - data['Стаж (лет)']) <0].count()[0])
display(data[(data['Возраст'] - data['Стаж (лет)']) <14].count()[0])

# удалим более ненужный признак стажа в годах
data.drop('Стаж (лет)', axis=1, inplace=True)
# Out:
# <ipython-input-137-3b12538bf8bd>:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   display(data[(data['Возраст'] - data['Стаж (лет)']) <0].count()[0])
# 7
# <ipython-input-137-3b12538bf8bd>:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   display(data[(data['Возраст'] - data['Стаж (лет)']) <14].count()[0])
# 73

# %% [markdown]
# - Однозначными аномалиями по стажу являются точки выше синей линии, показывающей прямую зависимость стажа от возраста соискателя: таких точек 7 штук.
# - Под вопросом также находятся точки между двумя линиями: это соискатели, начавшие трудовую карьеру до 14 лет, что затруднительно и по возрастным причинам, и по законодательным: еще 66 точек.
# - Наибольшее количество соискателей находятся в возрасте от 20 до 60 лет и обадают стажем от 0 до 45 лет, при этом обращают на себя внимание соискатели в возрасте старше 40 лет без опыта работы.
# - По цвету точек становится понятно, что основная масса соискателей - из Москвы, впрочем становится очевидным отсуствие зависимости представленности от города.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
fig = px.line(data.groupby('Возраст', as_index=False).mean(numeric_only=True), x='Возраст', y='ЗП (руб)', title='Зависимость средней зарплаты от возраста')
fig.show()

fig = px.box(data, x='Пол', y='ЗП (руб)', title='Зависимость средней зарплаты от пола')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - С увеличением возраста до 40 лет растут зарплатные ожидания
# - Девушки ожидают меньше зарплату чем мужчины (60к медиана у мужчин против 48к у женщин)

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
print(f'Начальное число записей: {data.shape[0]}')

dupl_columns = list(data.columns)

mask = data.duplicated(subset=dupl_columns)
duplicates = data[mask]
print(f'Число найденных дубликатов: {duplicates.shape[0]}')

data.drop_duplicates(subset=dupl_columns, inplace=True)
print(f'Результирующее число записей: {data.shape[0]}')
# Out:
# Начальное число записей: 44744
# Число найденных дубликатов: 161
# Результирующее число записей: 44583

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
data.isnull().sum()
# Out:
# Ищет работу на должность:            0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                170
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# Полная занятость                     0
# Частичная занятость                  0
# Проектная работа                     0
# Стажировка                           0
# Волонтерство                         0
# Вахтовый метод                       0
# Гибкий график                        0
# Удаленная работа                     0
# Полный день                          0
# Сменный график                       0
# ЗП (руб)                             0
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Заполним пропуски в столбце стаж
data.fillna({'Опыт работы (месяц)': data['Опыт работы (месяц)'].median()}, inplace=True)

# Ответим на вопрос:
# Чему равно результирующее среднее значение в столбце «Опыт работы (месяц)» после заполнения пропусков?
print(round(data['Опыт работы (месяц)'].mean(),0))

# Удаляем записи, в которых есть хотя пропуски в оставшихся столбцах с местом работы и должностью
data.dropna(how='any', axis=0, inplace=True)

data.info()
# Out:
# 114.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 44581 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44581 non-null  object
#  1   Последнее/нынешнее место работы  44581 non-null  object
#  2   Последняя/нынешняя должность     44581 non-null  object
#  3   Обновление резюме                44581 non-null  datetime64[ns]
#  4   Авто                             44581 non-null  object
#  5   Образование                      44581 non-null  object
#  6   Пол                              44581 non-null  object
#  7   Возраст                          44581 non-null  int64
#  8   Опыт работы (месяц)              44581 non-null  float64
#  9   Город                            44581 non-null  object
#  10  Готовность к переезду            44581 non-null  bool
# ...

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
outliers = data[(data['ЗП (руб)'] > 1000000) | (data['ЗП (руб)'] < 1000)]
print(outliers.shape[0])

# Удалим такие резюме
data.drop(outliers.index, axis=0, inplace=True)
print(f'Результирующее число записей: {data.shape[0]}')
# Out:
# 89
# Результирующее число записей: 44492

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
outliers = data[data['Опыт работы (месяц)'] / 12 > data['Возраст']]
print(outliers.shape[0])

# Удалим такие резюме
data.drop(outliers.index, axis=0, inplace=True)
print(f'Результирующее число записей: {data.shape[0]}')
# Out:
# 7
# Результирующее число записей: 44485

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
age_log = np.log(data['Возраст'])
histplot = sns.histplot(age_log, bins=30, ax=ax)
histplot.axvline(age_log.mean(), color='k', lw=2)
histplot.axvline(age_log.mean()+ 3 * age_log.std(), color='k', ls='--', lw=2)
histplot.axvline(age_log.mean()- 3 * age_log.std(), color='k', ls='--', lw=2)
histplot.set_title('Логарифмическое распределение возраста', fontsize = 18);

# Напишем функцию, которая реализует алгоритм метода z-отклонения (3 сигм)
def outliers_z_score_mod(data, feature, left=3, right=3, log_scale=False):
    if log_scale:
        x = np.log(data[feature])
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# применим функцию к таблице
outliers, data = outliers_z_score_mod(data, 'Возраст', left=3,  right=4, log_scale=True)

print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(outliers['Возраст'])
# Out:
# Число выбросов по методу z-отклонения: 3
# 31137     15
# 32950     15
# 33654    100
# Name: Возраст, dtype: int64

# %% [markdown]
# - Логарифмическое распределение возраста имеет небольшую асимметрию: левосторонняя ориентация, распределение напоминает слегка перекошенное нормальное.
# - Обнаружено 3 выброса. В категорию выбросов попали соискатели с возрастом 15 лет (2 резюме) и 100 лет (1 резюме).
