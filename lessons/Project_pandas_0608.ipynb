# %%
import numpy as np
import pandas as pd

# %%
# %%time
data_base=pd.read_csv('train.csv')
# Out:
# Wall time: 67.2 ms

# %%
data=data_base.copy()

# %%
data.shape
# Out:
# (10000, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
#data.drop('Healthcare_1',axis=1,inplace=True)
data=data.drop('Healthcare_1',axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.4+ MB

# %%
data.loc[data.HouseYear>2021].shape
# Out:
# (2, 19)

# %%
data.loc[data.HouseYear>2021]
#data[data.HouseYear>2021]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330         B         B        30
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 1497      6141        10            3        6       B  254084.534396
# 4189      4756        16            5        8       B  243028.603096

# %%
data.loc[data['HouseYear']==20052011,'HouseYear']=2008

# %%
data.loc[data['HouseYear']==4968,'HouseYear']=1968

# %%
data.loc[4189]
# Out:
# Id                  11607
# DistrictId            147
# Rooms                   2
# Square            44.7918
# LifeSquare        28.3604
# KitchenSquare           5
# Floor                   4
# HouseFloor              9
# HouseYear            1968
# Ecology_1        0.319809
# Ecology_2               B
# Ecology_3               B
# Social_1               25
# Social_2             4756
# Social_3               16
# Helthcare_2             5
# Shops_1                 8
# Shops_2                 B
# Price              243029
# Name: 4189, dtype: object

# %%
data.loc[data.Rooms>5]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 8849  14865           9   10.0  60.871266   38.420681           10.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377         22.0       2002   0.090799         B         B        74
# 1454        17.0       2014   0.007122         B         B         1
# 2170         9.0       1969   0.033494         B         B        66
# 8849         2.0       1994   0.161532         B         B        25
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 377      19083         2            5       15       B  317265.323792
# 1454       264         0            0        1       B   78364.616704
# ...

# %%
data.loc[data.Rooms==19,'Rooms']=1

# %%
data.loc[data.Rooms==10,'Rooms']=2

# %%
data.loc[377,'Rooms']=2

# %%
data.DistrictId.unique()
# Out:
# array([ 35,  41,  53,  58,  99,  59, 154,  74,   1,  23,  28,  31,  13,
#         57,  27,  85,  34,  19,   0,  48,  54, 150,  11,  50,  61,  44,
#         90, 200,  43, 177, 101,  38,  21, 103,  98, 170,  94,   5,  88,
#         47,   6,  52,  62,  77,  79,   9, 156,  69, 108,  96, 169,  18,
#        148, 128,  10, 144, 120,  39,   7,  84, 123, 159,  70, 129,   3,
#         95,  78,  45,  15, 121,  49,  25,   2, 127,  56, 109,  46,  17,
#        119,  80,  86,  83, 137,  91,  92, 118, 187,  36, 106, 161,  22,
#         63, 167, 113,  66,  29,  37,  20,   8, 181,  40,  93,  30,  81,
#        107, 130, 100,  12, 125,  67,  26,  89,  24, 111, 138,  64, 124,
#        183,  55, 157, 151,  33,  87, 126, 155, 164, 105, 110, 132,  71,
#         73, 189,  75, 122, 163, 141,  76, 115, 139, 143, 201, 165, 190,
#        193, 174,  60, 114, 172, 134, 117, 149, 153, 131, 145,  82, 160,
#         42,  32, 133, 208, 171, 176, 173, 147,  97, 142, 195, 180, 196,
# ...

# %%
data.DistrictId.nunique()
# Out:
# 205

# %%
data.loc[data['DistrictId']==100,'Price'].mean()
# Out:
# 268783.76840521663

# %%
data.loc[data['DistrictId']==105,'Price'].mean()
# Out:
# 224550.83595417123

# %%
data.loc[data['DistrictId']==110,'Price'].mean()
# Out:
# 237364.7794076715

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.887100     56.315775    37.199645
# std     4859.01902     43.587592      0.813892     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000      6.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor    HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean        6.273300      8.526700     12.609400   1984.86600      0.118858
# ...

# %%
index_array_square=data.loc[data.Square<15].index

# %%
data=data.drop(index_array_square,axis=0)

# %%
data=data.reset_index(drop=True)

# %%
data.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   9987.000000  9987.000000  9987.000000  9987.000000  7874.000000
# mean    8382.091619    50.425653     1.887654    56.383254    37.230601
# std     4859.654766    43.599980     0.813586    20.988877    86.302686
# min        0.000000     0.000000     0.000000    16.117154     0.370619
# 25%     4167.500000    20.000000     1.000000    41.789013    22.801890
# 50%     8393.000000    36.000000     2.000000    52.540107    32.786483
# 75%    12591.500000    75.000000     2.000000    65.925906    45.137721
# max    16798.000000   209.000000     6.000000   641.065193  7480.592129
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    9987.000000  9987.000000  9987.000000  9987.000000  9987.000000
# mean        6.279764     8.524782    12.614399  1984.866727     0.118849
# std        28.578875     5.234063     6.770878    18.413561     0.119047
# ...

# %%
data.loc[data.LifeSquare>data.Square.max()]
# Out:
#          Id  DistrictId  Rooms     Square   LifeSquare  KitchenSquare  Floor  \
# 4323  16550          27    3.0  81.694417  7480.592129            1.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4323        17.0       2016   0.017647         B         B         2
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 4323       469         0            0        0       B  217357.492366

# %%
data.Square.max()
# Out:
# 641.0651927456407

# %%
data.loc[4323,'LifeSquare']=data.loc[4323,'LifeSquare']/100

# %%
data.loc[4323,'LifeSquare']
# Out:
# 74.80592128925201

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9987 entries, 0 to 9986
# Data columns (total 19 columns):
# Id               9987 non-null int64
# DistrictId       9987 non-null int64
# Rooms            9987 non-null float64
# Square           9987 non-null float64
# LifeSquare       7874 non-null float64
# KitchenSquare    9987 non-null float64
# Floor            9987 non-null int64
# HouseFloor       9987 non-null float64
# HouseYear        9987 non-null int64
# Ecology_1        9987 non-null float64
# Ecology_2        9987 non-null object
# Ecology_3        9987 non-null object
# Social_1         9987 non-null int64
# Social_2         9987 non-null int64
# Social_3         9987 non-null int64
# Helthcare_2      9987 non-null int64
# Shops_1          9987 non-null int64
# Shops_2          9987 non-null object
# Price            9987 non-null float64
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# # 1 способ  LifeSquare

# %%
index_array_lifesquare=data.loc[data.LifeSquare.isna()].index

# %%
data.drop(index_array_lifesquare,axis=0,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9987 entries, 0 to 9986
# Data columns (total 19 columns):
# Id               9987 non-null int64
# DistrictId       9987 non-null int64
# Rooms            9987 non-null float64
# Square           9987 non-null float64
# LifeSquare       7874 non-null float64
# KitchenSquare    9987 non-null float64
# Floor            9987 non-null int64
# HouseFloor       9987 non-null float64
# HouseYear        9987 non-null int64
# Ecology_1        9987 non-null float64
# Ecology_2        9987 non-null object
# Ecology_3        9987 non-null object
# Social_1         9987 non-null int64
# Social_2         9987 non-null int64
# Social_3         9987 non-null int64
# Helthcare_2      9987 non-null int64
# Shops_1          9987 non-null int64
# Shops_2          9987 non-null object
# Price            9987 non-null float64
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# # 2 способ LifeSquare

# %%
data['LifeSquare']=data['LifeSquare'].fillna(data['LifeSquare'].mean())
#data['LifeSquare'].fillna(data['LifeSquare'].median())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9987 entries, 0 to 9986
# Data columns (total 19 columns):
# Id               9987 non-null int64
# DistrictId       9987 non-null int64
# Rooms            9987 non-null float64
# Square           9987 non-null float64
# LifeSquare       9987 non-null float64
# KitchenSquare    9987 non-null float64
# Floor            9987 non-null int64
# HouseFloor       9987 non-null float64
# HouseYear        9987 non-null int64
# Ecology_1        9987 non-null float64
# Ecology_2        9987 non-null object
# Ecology_3        9987 non-null object
# Social_1         9987 non-null int64
# Social_2         9987 non-null int64
# Social_3         9987 non-null int64
# Helthcare_2      9987 non-null int64
# Shops_1          9987 non-null int64
# Shops_2          9987 non-null object
# Price            9987 non-null float64
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# # 3 способ LifeSquare

# %%
(data.Square/data.LifeSquare).mean()
# Out:
# 2.029438769578675

# %%
square_lifesquare=(data.Square/data.LifeSquare).median()
square_lifesquare
# Out:
# 1.6193150074679417

# %%
data['LifeSquare']=data.LifeSquare.fillna(data['Square']/square_lifesquare)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9987 entries, 0 to 9986
# Data columns (total 19 columns):
# Id               9987 non-null int64
# DistrictId       9987 non-null int64
# Rooms            9987 non-null float64
# Square           9987 non-null float64
# LifeSquare       9987 non-null float64
# KitchenSquare    9987 non-null float64
# Floor            9987 non-null int64
# HouseFloor       9987 non-null float64
# HouseYear        9987 non-null int64
# Ecology_1        9987 non-null float64
# Ecology_2        9987 non-null object
# Ecology_3        9987 non-null object
# Social_1         9987 non-null int64
# Social_2         9987 non-null int64
# Social_3         9987 non-null int64
# Helthcare_2      9987 non-null int64
# Shops_1          9987 non-null int64
# Shops_2          9987 non-null object
# Price            9987 non-null float64
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   9987.000000  9987.000000  9987.000000  9987.000000  9987.000000
# mean    8382.091619    50.425653     1.887654    56.383254    36.290065
# std     4859.654766    43.599980     0.813586    20.988877    17.985154
# min        0.000000     0.000000     0.000000    16.117154     0.370619
# 25%     4167.500000    20.000000     1.000000    41.789013    25.593960
# 50%     8393.000000    36.000000     2.000000    52.540107    36.290065
# 75%    12591.500000    75.000000     2.000000    65.925906    41.446202
# max    16798.000000   209.000000     6.000000   641.065193   638.163193
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    9987.000000  9987.000000  9987.000000  9987.000000  9987.000000
# mean        6.279764     8.524782    12.614399  1984.866727     0.118849
# std        28.578875     5.234063     6.770878    18.413561     0.119047
# ...

# %%
data.loc[data.KitchenSquare>100].index
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1063  14656          62    1.0   47.100719   46.447960         2014.0      4
# 2966   7441          62    3.0  114.734473  112.589083          112.0      3
# 4646  12552          58    3.0  116.405693  113.109653          112.0      3
# 8573  14679          81    1.0   32.276663   19.278394         1970.0      6
# 9882   2737          27    3.0  123.430072  125.806981          123.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1063         1.0       2014   0.072158         B         B         2
# 2966         3.0       2015   0.072158         B         B         2
# 4646         3.0       2016   0.437885         B         B        23
# 8573         1.0       1977   0.006076         B         B        30
# 9882        10.0       2015   0.017647         B         B         2
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# ...

# %%
index_large_kitchen=data.loc[data.KitchenSquare>100].index
data.drop(index_large_kitchen,axis=0,inplace=True)

# %%
data.loc[data.KitchenSquare<1].shape
# Out:
# (695, 19)

# %%
data.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   9982.000000  9982.000000  9982.000000  9982.000000  9982.000000
# mean    8381.074334    50.421859     1.887497    56.368023    36.266444
# std     4859.540518    43.608822     0.813464    20.965068    17.933503
# min        0.000000     0.000000     0.000000    16.117154     0.370619
# 25%     4167.250000    20.000000     1.000000    41.788428    25.591317
# 50%     8392.500000    36.000000     2.000000    52.539909    36.290065
# 75%    12590.750000    75.000000     2.000000    65.907611    41.422598
# max    16798.000000   209.000000     6.000000   641.065193   638.163193
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    9982.000000  9982.000000  9982.000000  9982.000000  9982.000000
# mean        5.849028     8.526949    12.618914  1984.855440     0.118847
# std         4.812062     5.234413     6.769158    18.408114     0.119022
# ...

# %%
data.loc[data.Floor>data.HouseFloor,'HouseFloor']=data.loc[data.Floor>data.HouseFloor,'Floor']

# %%
data.loc[data.Floor>data.HouseFloor]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   9982.000000  9982.000000  9982.000000  9982.000000  9982.000000
# mean    8381.074334    50.421859     1.887497    56.368023    36.266444
# std     4859.540518    43.608822     0.813464    20.965068    17.933503
# min        0.000000     0.000000     0.000000    16.117154     0.370619
# 25%     4167.250000    20.000000     1.000000    41.788428    25.591317
# 50%     8392.500000    36.000000     2.000000    52.539909    36.290065
# 75%    12590.750000    75.000000     2.000000    65.907611    41.422598
# max    16798.000000   209.000000     6.000000   641.065193   638.163193
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    9982.000000  9982.000000  9982.000000  9982.000000  9982.000000
# mean        5.849028     8.526949    13.439090  1984.855440     0.118847
# std         4.812062     5.234413     6.086644    18.408114     0.119022
# ...
